# %% [markdown]
# <a href="https://colab.research.google.com/github/HendrikMonterrey/evidencias-entregas2039_101-HendrikMonterrey/blob/main/Activity_7_Proof.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = '/content/antropometria-dataset.csv'

# %%
import pandas as pd

data = pd.read_csv(r'/content/antropometria-dataset.csv')
df = pd.DataFrame(data)

print(df)
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
hist_plot = df['sistol'].plot(kind='hist')

# %%
hist_plot = df['diastol'].plot(kind='hist')

# %%
hist_plot = df['peso'].plot(kind='hist'),

# %%
hist_plot = df['cintura'].plot(kind='hist'),
bins =15

# %%
import seaborn as sns

path = "/content/antropometria-dataset.csv"

df = pd.read_csv(path)

sns.lmplot(x='peso',
           y='cintura',
           data=df
          )
plt.title('Scatterplot Weight vs Cintura')
plt.show()

# %%
sns.lmplot(x='sistol',
           y='peso',
           hue ='sexo',
           data=df
          )
plt.title('Scatterplot Weight vs Cintura')
plt.show()

# %%
sns.lmplot(x='sistol',
           y='diastol',
           hue ='sexo',
           data=df
          )
plt.title('Scatterplot Weight vs Cintura')
plt.show()
