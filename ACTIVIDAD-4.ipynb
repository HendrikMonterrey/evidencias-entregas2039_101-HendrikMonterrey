# %% [markdown]
# <a href="https://colab.research.google.com/github/HendrikMonterrey/evidencias-entregas2039_101-HendrikMonterrey/blob/main/ACTIVIDAD-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = '/antropometria-dataset-2.csv'

# %%
import pandas as pd

data = pd.read_csv(r'/antropometria-dataset-2.csv')
df = pd.DataFrame(data)

print(df)
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
pd.pivot_table(df,
               index = 'sexo',
               values = 'peso',
               aggfunc =  'mean'
               )
# Out:
#            peso
# sexo
# 1     67.131228
# 2     62.700503

# %%
pd.pivot_table(df,
               index = 'desc_ent',
               values = 'peso',
               aggfunc = 'mean')
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
pd.pivot_table(df,
               index = 'desc_ent',
               values = 'peso',
               columns = 'sexo',
               aggfunc = 'median')
# Out:
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# NAYARIT                          69.0500  63.7000
# ...

# %%
df['peso'].plot(kind = 'box',
          #whis = (0, 100),
          #showfliers = False,
               figsize = (8, 5),
               vert = False,
               color = 'r',
)
# Out:
# <Axes: >

# %%
pd.pivot_table(df,
               index = 'desc_ent',
               values = 'peso',
               columns = 'sexo',
               aggfunc = 'mean')
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# MICHOACAN DE OCAMPO              66.374612  63.784311
# ...

# %%
path = '/adult (1).csv'

# %%
import pandas as pd

data = pd.read_csv(r'/adult (1).csv')
df = pd.DataFrame(data)

# %%
pd.pivot_table(df,
               index = 'marital-status',
               values = 'age',
               columns = ['sex', 'education'],
               aggfunc = 'median')
# Out:
# sex                     Female                                               \
# education                 10th  11th  12th  1st-4th  5th-6th  7th-8th   9th
# marital-status
#  Divorced                 45.0  41.0  41.0     64.0     53.0     52.0  46.0
#  Married-AF-spouse         NaN   NaN   NaN      NaN      NaN      NaN   NaN
#  Married-civ-spouse       32.0  42.0  34.0     44.5     43.0     46.0  40.5
#  Married-spouse-absent    39.0  30.0  25.5     33.0     50.0     44.0  49.0
#  Never-married            18.0  18.0  18.0     32.0     32.0     31.0  26.5
#  Separated                34.0  35.5  35.0     50.0     39.0     45.0  45.0
#  Widowed                  60.0  56.0  56.0     63.0     65.0     64.0  63.0
#  test_category_female      NaN   NaN   NaN      NaN      NaN      NaN   NaN
#  test_category_male        NaN   NaN   NaN      NaN      NaN      NaN   NaN
#
# sex                                                       ...  Male  \
# ...

# %%
pd.pivot_table(df,
               index = 'marital-status',
               values = 'age',
               columns = 'education',
               aggfunc = 'mean')
# Out:
# education                    10th       11th       12th    1st-4th    5th-6th  \
# marital-status
#  Divorced               44.133333  41.230769  41.333333  62.700000  53.700000
#  Married-AF-spouse            NaN        NaN        NaN        NaN        NaN
#  Married-civ-spouse     46.126074  42.559322  41.892308  47.888889  45.872093
#  Married-spouse-absent  42.000000  34.052632  38.000000  41.416667  42.650000
#  Never-married          23.961219  22.261092  23.206897  31.717949  30.651685
#  Separated              39.530612  36.937500  36.000000  49.777778  43.722222
#  Widowed                59.256410  55.973684  60.600000  62.588235  67.785714
#  test_category_female         NaN        NaN        NaN        NaN        NaN
#  test_category_male           NaN        NaN        NaN        NaN        NaN
#
# education                 7th-8th        9th   Assoc-acdm   Assoc-voc  \
# marital-status
#  Divorced               49.452055  46.281250    41.064039   40.653846
# ...
